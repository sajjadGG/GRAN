# %%
from pickle import load,dump
import networkx as nx
import numpy as np

# %%
l =[]
with open('tmp/gen_graphs_aug.pkl','rb') as f:
    l=load(f)

# %%
len(l)
# Out:
# 10

# %%
nx.draw(l[4])

# %%
res=[]
with open('tmp/result.pkl','rb') as f:
    res=load(f)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,10))
plt.title("train loss with cumulative augmentation")
plt.plot(res['train_step'],res['train_loss'],)
plt.show()

# %%
res=[]
with open('exp/GRAN\GRANMixtureBernoulli_grid_2022-Feb-07-02-31-28_16344\\train_stats.p','rb') as f:
    res=load(f)

# %%
plt.figure(figsize=(8,10))
plt.title("train loss with cumulative augmentation")
plt.plot(res['train_step'],res['train_loss'],)
plt.show()

# %%
nx.draw(nx.Graph(l[0]))

# %%
import torch

# %%
d = []
with open('tmp/example5.pkl' , 'rb') as f:
    d = load(f)

# %%
d = np.array(d[0].detach().cpu())

# %%
nx.draw(nx.Graph(d[:9,:9]))

# %%
nx.draw(nx.Graph(d[9:18,9:18]))

# %%
nx.draw(nx.Graph(d[:27,:27]))
